# %% [markdown]
# # Data Science Jobs Analyze

# %% [markdown]
# Group:
# * Anchal
# * Angela
# * Larissa
# * Fabio
# * Felipe

# %% [markdown]
# This program read information coming from the data frame "df_jobs" generated by the "Data Science Jobs Analyze - Web Scraping" script and provides some analysis about the main caracteristics of Data Science Job opportunities in Toronto.

# %%
# Importing Libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
df_jobs = pd.read_excel('output/df_jobs_out.xlsx')

# %%
# Starting the Analysis  

# Checking how many records we are missing:
df_jobs.isnull().sum()
# Out:
# Province        0
# City            0
# Job_ID          0
# JobTitle_x      0
# Position        0
# CompanyName     0
# JobType         0
# Salary          0
# KeyWord         0
# Skill           0
# Category        0
# InUoTProgram    0
# dtype: int64

# %%
# looking at the descriptive statistics for the dataframe:
df_jobs.describe(include='all')
# Out:
#        Province     City            Job_ID      JobTitle_x        Position  \
# count      4685     4685              4685            4685            4685
# unique       13       99               984               1             805
# top          ON  Toronto  d01e01ae79264266  Data Scientist  Data Scientist
# freq       2296     1480                21            4685             466
#
#        CompanyName       JobType        Salary KeyWord  Skill Category  \
# count         4685          4685          4685    4685   4685     4685
# unique         552            10            68      67     52        6
# top     Amazon.com  Not Informed  Not Informed   Excel  Excel     Hard
# freq            79          4017          4378     410    410     2809
#
#        InUoTProgram
# count          4685
# unique            2
# top              NO
# freq           2914

# %%
df_jobs.head()
# Out:
#   Province     City            Job_ID      JobTitle_x  \
# 0       ON  Toronto  1214066c87f66a66  Data Scientist
# 1       ON  Toronto  1214066c87f66a66  Data Scientist
# 2       ON  Toronto  1214066c87f66a66  Data Scientist
# 3       ON  Toronto  1214066c87f66a66  Data Scientist
# 5       ON  Toronto  1214066c87f66a66  Data Scientist
#
#                            Position                CompanyName       JobType  \
# 0  Data Scientist, Machine Learning  Confidential Tech Company  Not Informed
# 1  Data Scientist, Machine Learning  Confidential Tech Company  Not Informed
# 2  Data Scientist, Machine Learning  Confidential Tech Company  Not Informed
# 3  Data Scientist, Machine Learning  Confidential Tech Company  Not Informed
# 5  Data Scientist, Machine Learning  Confidential Tech Company  Not Informed
#
#                       Salary KeyWord                    Skill   Category  \
# 0  $80,000 - $100,000 a year  Python                   Python       Hard
# 1  $80,000 - $100,000 a year      AI  Artificial Intelligence      major
# 2  $80,000 - $100,000 a year     *R                         R       Hard
# 3  $80,000 - $100,000 a year  Master                   Master  Education
# 5  $80,000 - $100,000 a year  Hadoop                   Hadoop       Hard
#
#   InUoTProgram
# 0          YES
# 1          YES
# 2           NO
# 3           NO
# 5          YES

# %%
# Job opportunities analyzed
len(df_jobs.groupby(['Job_ID']).size())
# Out:
# 984

# %%
# Data Science job opportunities by Province

df_province_jobs = df_jobs.groupby(['Province','Job_ID']).size().reset_index().groupby('Province').size().sort_values(ascending=False)
df_province_jobs = df_province_jobs.head(10)
df_province_jobs = df_province_jobs.sort_values(ascending=True)
df_province_jobs.plot(kind='barh', stacked=False, rot = 0, figsize=(20 , 7), title = 'Data Science job opportunities by Province');
# We can try to replace this graph to the map plot

# %%
# 10 Cities with more opportunities

df_city_jobs = df_jobs.groupby(['City','Job_ID']).size().reset_index().groupby('City').size().sort_values(ascending=False)
df_city_jobs = df_city_jobs.head(10)
df_city_jobs.plot(kind='bar', stacked=False, rot = 0, figsize=(20, 7), title = '10 Cities with more opportunities');

# %%
# Top 3 Cities by Province
#Ontario
df_jobs_ON = df_jobs.loc [df_jobs['Province'] == 'ON']
df_city_jobs_ON = df_jobs_ON.groupby(['City','Job_ID']).size().reset_index().groupby('City').size().sort_values(ascending=False)

#British Columbia
df_jobs_BC = df_jobs.loc [df_jobs['Province'] == 'BC']
df_city_jobs_BC = df_jobs_BC.groupby(['City','Job_ID']).size().reset_index().groupby('City').size().sort_values(ascending=False)

#Alberta
df_jobs_AB = df_jobs.loc [df_jobs['Province'] == 'AB']
df_city_jobs_AB = df_jobs_AB.groupby(['City','Job_ID']).size().reset_index().groupby('City').size().sort_values(ascending=False)

#Quebec
df_jobs_QC = df_jobs.loc [df_jobs['Province'] == 'QC']
df_city_jobs_QC = df_jobs_QC.groupby(['City','Job_ID']).size().reset_index().groupby('City').size().sort_values(ascending=False)

#Saskatwan 
df_jobs_SK = df_jobs.loc [df_jobs['Province'] == 'SK']
df_city_jobs_SK = df_jobs_SK.groupby(['City','Job_ID']).size().reset_index().groupby('City').size().sort_values(ascending=False)

#Nova Scottia 
df_jobs_NS = df_jobs.loc [df_jobs['Province'] == 'NS']
df_city_jobs_NS = df_jobs_NS.groupby(['City','Job_ID']).size().reset_index().groupby('City').size().sort_values(ascending=False)

#Manitoba 
df_jobs_MB = df_jobs.loc [df_jobs['Province'] == 'MB']
df_city_jobs_MB = df_jobs_MB.groupby(['City','Job_ID']).size().reset_index().groupby('City').size().sort_values(ascending=False)


#New Brunswick 
df_jobs_NB = df_jobs.loc [df_jobs['Province'] == 'NB']
df_city_jobs_NB = df_jobs_NB.groupby(['City','Job_ID']).size().reset_index().groupby('City').size().sort_values(ascending=False)

# %%
# Top 3 Cities by Province
plt.subplots_adjust(left=None, bottom=None, right=None, top=0.9, wspace=None, hspace=None)
plt.figure()
plt.subplot(2,4,1)
df_city_jobs_ON.head(3).plot(kind='bar',stacked=False, rot = 0, figsize=(20, 4))
plt.title('Top 3 Cities in ON - # Jobs')
plt.ylim((0,280))

plt.subplot(2,4,2)
df_city_jobs_BC.head(3).plot(kind='bar',stacked=False, rot = 0, figsize=(20, 4))
plt.title('Top 3 Cities in BC - # Jobs')
plt.ylim((0,280))


plt.subplot(2,4,3)
df_city_jobs_QC.head(3).plot(kind='bar',stacked=False, rot = 0, figsize=(20, 4))
plt.title('Top 3 Cities in QC - # Jobs')
plt.ylim((0,280))


plt.subplot(2,4,4)
df_city_jobs_AB.head(3).plot(kind='bar',stacked=False, rot = 0, figsize=(20, 4))
plt.title('Top 3 Cities in AB - # Jobs')
plt.ylim((0,280))


plt.subplot(2,4,5)
plt.subplots_adjust(left=None, bottom=None, right=None, top=2.5, wspace=None, hspace=None)
df_city_jobs_SK.head(3).plot(kind='bar',stacked=False, rot = 0, figsize=(20, 4))
plt.title('Top 3 Cities in SK - # Jobs')
plt.ylim((0,50))


plt.subplot(2,4,6)
plt.subplots_adjust(left=None, bottom=None, right=None, top=2.5, wspace=None, hspace=None)
df_city_jobs_NS.head(3).plot(kind='bar',stacked=False, rot = 0, figsize=(20, 4))
plt.title('Top 3 Cities in NS - # Jobs')
plt.ylim((0,50))


plt.subplot(2,4,7)
plt.subplots_adjust(left=None, bottom=None, right=None, top=2.5, wspace=None, hspace=None)
df_city_jobs_MB.head(3).plot(kind='bar',stacked=False, rot = 0, figsize=(20, 4))
plt.title('Top 3 Cities in MB - # Jobs')
plt.ylim((0,50))


plt.subplot(2,4,8)
plt.subplots_adjust(left=None, bottom=None, right=None, top=2.5, wspace=None, hspace=None)
df_city_jobs_NB.head(3).plot(kind='bar',stacked=False, rot = 0, figsize=(20, 4))
plt.title('Top 3 Cities in NB - # Jobs')
plt.ylim((0,50))
# Out:
# (0, 50)

# %%
# Top 3 required Data Science Hard skills by the main provinces. E.g Toronto X Vancouver 

#Ontario
df_skills_ON = df_jobs.loc [(df_jobs['City'] == 'Toronto') & (df_jobs['Category'] == 'Hard')]
df_city_skills_ON = df_skills_ON.groupby(['Skill','Job_ID']).size().reset_index().groupby('Skill').size().sort_values(ascending=False)


#British Columbia
df_skills_BC = df_jobs.loc [(df_jobs['City'] == 'Vancouver') & (df_jobs['Category'] == 'Hard')]
df_city_skills_BC = df_skills_BC.groupby(['Skill','Job_ID']).size().reset_index().groupby('Skill').size().sort_values(ascending=False)


# Top 3 required Data Science skills by the main provinces. E.g Toronto X Vancouver - Plots
plt.subplots_adjust(left=None, bottom=1, right=None, top=5, wspace=None, hspace=None)
plt.figure()
plt.subplot(1,2,1)
df_city_skills_ON.head(5).plot(kind='bar',stacked=False, rot = 0, figsize=(20, 4))
plt.title('Top 3 Hard skills in ON')
plt.ylim((0,200))

plt.subplot(1,2,2)
df_city_skills_BC.head(5).plot(kind='bar',stacked=False, rot = 0, figsize=(20, 4))
plt.title('Top 3 Hard skills in BC')
plt.ylim((0,200))
# Out:
# (0, 200)

# %%
# Top 3 required Data Science Soft skills by the main provinces. E.g Toronto X Vancouver 

#Ontario
df_skills_ON = df_jobs.loc [(df_jobs['City'] == 'Toronto') & (df_jobs['Category'] == 'Soft')]
df_city_skills_ON = df_skills_ON.groupby(['Skill','Job_ID']).size().reset_index().groupby('Skill').size().sort_values(ascending=False)


#British Columbia
df_skills_BC = df_jobs.loc [(df_jobs['City'] == 'Vancouver') & (df_jobs['Category'] == 'Soft')]
df_city_skills_BC = df_skills_BC.groupby(['Skill','Job_ID']).size().reset_index().groupby('Skill').size().sort_values(ascending=False)


# Top 3 required Data Science skills by the main provinces. E.g Toronto X Vancouver - Plots
plt.subplots_adjust(left=None, bottom=1, right=None, top=5, wspace=None, hspace=None)
plt.figure()
plt.subplot(1,2,1)
df_city_skills_ON.head(5).plot(kind='bar',stacked=False, rot = 0, figsize=(20, 4))
plt.title('Top 3 Soft skills in ON')
plt.ylim((0,30))

plt.subplot(1,2,2)
df_city_skills_BC.head(5).plot(kind='bar',stacked=False, rot = 0, figsize=(20, 4))
plt.title('Top 3 Soft skills in BC')
plt.ylim((0,30))
# Out:
# (0, 30)

# %%
# Which skills companies are looking for?

# %%
# Top 10 required Data Science skills by Category in Canada

df_skill_jobs = df_jobs.groupby(['Skill','Job_ID']).size().reset_index().groupby('Skill').size().sort_values(ascending=False)
df_skill_jobs = df_skill_jobs.head(10)
df_skill_jobs.plot(kind='bar', stacked=False, rot = 0, figsize=(20 , 7), title = 'Quantity of Jobs by Skill')
# Change this plot by category

# %%
# How much will we be paid?

# %%
# How Data  Science program  will help us to get a job?

#Ontario
df_UoT_ON = df_jobs.loc [(df_jobs['Province'] == 'ON') & (df_jobs['Category'] == 'Soft')]
df_UoT_ON_1 = df_UoT_ON.groupby(['InUoTProgram','Job_ID']).size().reset_index().groupby('InUoTProgram').size().sort_values(ascending=False)
print(df_UoT_ON_1)
df_UoT_ON_1.plot(kind='pie', stacked=False, rot = 0, figsize=(7 , 7), title = 'How much this curse is helping us with the skills required in ON')
# Out:
# InUoTProgram
# YES    29
# NO     12
# dtype: int64

# %%
# Python, Big Data, Statistics and AI

# %%
# Most popular in the market: Python or R?

# %%
# % of job opportunities by skills

# Skills by Job
skills_job = pd.crosstab(df_jobs['Skill'],df_jobs['JobTitle_x'])
skills_job = skills_job.sort_values('Data Scientist',ascending=False)
skills_job = skills_job.head(10)
skills_job
# We can put this plot in %
# Out:
# JobTitle_x               Data Scientist
# Skill
# Excel                               410
# Python                              382
# Bachelor                            363
# PhD                                 275
# Computer Science                    231
# SQL                                 219
# Java                                202
# Master                              189
# R                                   172
# Artificial Intelligence             168
